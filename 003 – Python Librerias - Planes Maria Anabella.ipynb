# %% [markdown]
# # TP03 – Python Librerías

# %% [markdown]
# María Anabella Planes

# %% [markdown]
# ## Ejercicio 1 – Importación de librerías

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datos = np.array([15, 25, 35, 45, 55])
print(datos)
# Out:
# [15 25 35 45 55]

# %% [markdown]
# ## Ejercicio 2 – Dataset simple con Pandas

# %%
datos = {
    "estudiante": ["Ana", "Juan", "Carla", "Pedro", "Lucia"],
    "nota": [8, 6, 9, 5, 7]
}
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#   estudiante  nota
# 0        Ana     8
# 1       Juan     6
# 2      Carla     9
# 3      Pedro     5
# 4      Lucia     7

# %%
float(df["nota"].mean())
# Out:
# 7.0

# %%
int(df["nota"].max())
# Out:
# 9

# %%
int(df["nota"].min())
# Out:
# 5

# %% [markdown]
# ## Ejercicio 3 – Criterio de selección de herramientas

# %% [markdown]
# pandas: porque permite leer archivos CSV y manipular datasets tabulares\.
# matplotlib/plotly: porque permiten crear gráficos de distribución de datos\.
# keras: porque permite construir y entrenar modelos de Machine Learning\.
# numpy: porque permite realizar operaciones matemáticas sobre matrices y arrays\.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=51094477-f6d3-4cf2-979a-1aed09b48d2d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
