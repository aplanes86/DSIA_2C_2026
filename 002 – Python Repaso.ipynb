# %% [markdown]
# # Planes María Anabella

# %% [markdown]
# ## Ejercicio 1 – Variables y operaciones

# %% [markdown]
# Crear variables para almacenar:

# %% [markdown]
# tu nombre
# tu edad
# tu ciudad
# Luego imprimir un mensaje con el siguiente formato:
# Hola, mi nombre es \_\_\_, tengo \_\_\_ años y vivo en \_\_\_\.

# %%
nombre= "Anabella"
edad= 40
ciudad= "Buenos Aires"

print(f"Hola, mi nombre es", nombre,"tengo", edad, "años y vivo en", ciudad,".")
# Out:
# Hola, mi nombre es Anabella tengo 40 años y vivo en Buenos Aires .

# %% [markdown]
# A continuación, crear dos variables numéricas a y b, asignarles valores y calcular:

# %% [markdown]
# suma
# resta
# multiplicación
# división
# Mostrar los resultados utilizando print\(\)\.

# %%
a = 7
b = 3

suma = a + b
resta = a - b
multiplicacion = a * b
división = a / b

print(f"La suma de a y b es", suma)
print(f"La resta de a y b es", resta)
print(f"La multiplicación de a y b es", multiplicacion)
print(f"La división de a y b es", división)
# Out:
# La suma de a y b es 10
# La resta de a y b es 4
# La multiplicación de a y b es 21
# La división de a y b es 2.3333333333333335

# %% [markdown]
# ## Ejercicio 2 – Condicionales

# %% [markdown]
# Crear un programa que:

# %% [markdown]
# Pida al usuario que ingrese su edad usando input\(\)
# Determine si la persona es mayor o menor de edad
# Mostrar uno de los siguientes mensajes:

# %% [markdown]
# Eres mayor de edad
# o
# Eres menor de edad

# %%
edad = int(input("Ingrese su edad:"))

if edad >= 21:
    print(f"Eres mayor de edad")
else:
    print(f"Eres menor de edad")
# Out:
# Eres menor de edad

# %% [markdown]
# ## Ejercicio 3 – Listas y bucles

# %% [markdown]
# Crear una lista con 5 números\. Utilizando un bucle for, imprimir cada número de la lista\.

# %% [markdown]
# Luego:

# %% [markdown]
# Calcular la suma total de los números
# Calcular el promedio
# Mostrar ambos resultados por pantalla\.

# %%
numeros = [1, 3, 5, 8, 10]

for numero in numeros:
    print(numero)   

suma = sum(numeros)
promedio = suma / len(numeros)
print(f"La suma de todos los numeros es: {suma}")
print(f"El promedio de los numeros es: {promedio}")
# Out:
# 1
# 3
# 5
# 8
# 10
# La suma de todos los numeros es: 27
# El promedio de los numeros es: 5.4

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=51094477-f6d3-4cf2-979a-1aed09b48d2d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
